# %%
import astropy.units as u
import astropy.constants as c
from astropy.coordinates import SkyCoord
from astropy.time import Time
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import glob
# %matplotlib inline

# %%
plt.rcParams['figure.figsize'] = (10, 10)
plt.rc('axes', labelsize=14)
plt.rc('axes', labelweight='bold')
plt.rc('axes', titlesize=16)
plt.rc('axes', titleweight='bold')
plt.rc('font', family='sans-serif')

# %% [markdown]
# # Lecture Notes
#
# example problem

# %%
from numpy.random import random

# %%
atoms = 1000
hl = 3.053*60
NPb = 0
NTl = 1000
h = 1
tmax = 1000
p = 1-2**(-h/hl)

# %%
tpoints= np.arange(0,tmax, h)
Tlpoints = []
Pbpoints = []

# %%
for t in tpoints:
    Tlpoints.append(NTl)
    Pbpoints.append(NPb)
    
    decay = 0
    for i in range(NTl):
        if random()<p:
            decay+=1
    NTl -= decay
    NPb += decay

# %%
plt.plot(Tlpoints)
plt.plot(Pbpoints);

# %%
def N(t):
    return atoms*2**(-1*t/hl)

# %%
def p(t):
    return 1-2**(-t/hl)

# %%
states = []
s=1
for a in range(atoms):
    probability = p(s)
    if probability >(0.5):
        states.append(1)
    else:
        states.append(0)

# %%
prob = p(1)
tpoints = np.arange(0.0,tmax,h)
for a in atoms:
    lost = prob*atoms

# %%
tpoints = np.arange(0,hl)
plt.plot(1-2**(-1*tpoints/hl));

# %%
p(1)*1000
# Out:
# 3.776817392159071

# %%
N=1000
z = random(N)
mu = np.log(2)/hl
#get decay times
t = (-1/mu)*np.log(1-z)
plt.plot(sorted(t))
plt.gca().invert_xaxis();
